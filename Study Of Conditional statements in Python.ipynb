# %% [markdown]
# #EXPERIMENT NUMBER 6
# # TITLE: STUDY OF CONDITIONAL STATEMENTS IN PYTHON
# ### NAME: DARSH JAIN
# ### PRN: 25070123037
# ### ENTC A2
# ### 02/02/26

# %%
#PROBLEM 1.a: Check whether the number is positive or negative.
num = int(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
else:
    print("The number is Negative")
# Out:
# Enter a number: 2
# The number is Positive

# %%
#Problem 1.b: Check whether the number is positive or negative or zero.
num = int(input("Enter a number: "))

if num > 0:
    print("The number is Positive")
elif num < 0:
    print("The number is Negative")
else:
    print("The number is Zero")
# Out:
# Enter a number: 3
# The number is Positive

# %%
#Problem 2: Check whether a number is even or odd.
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("The number is Even")
else:
    print("The number is Odd")
# Out:
# Enter a number: 3
# The number is Odd

# %%
#Problem 3: Find the largest of two numbers:

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
    print("The largest number is:", num1)
else:
    print("The largest number is:", num2)
# Out:
# Enter first number: 23
# Enter second number: 65
# The largest number is: 65

# %%
#Problem 4: Find the largest of three numbers

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("The largest number is:", a)
elif b >= a and b >= c:
    print("The largest number is:", b)
else:
    print("The largest number is:", c)
# Out:
# Enter first number: 76
# Enter second number: 98
# Enter third number: 12
# The largest number is: 98

# %%
#Problem 5: Get input from user for 5 subjects and find average. Calculate grade using if-elif-else.
#if avg>90 grade is o
#90<avg>80 grade is a+
#avg>70 grade a
#avg>60 grade b+
#avg>50 grade c
#avg>40 grade d


marks1 = int(input("Enter marks for subject 1: "))
marks2= int(input("Enter marks for subject 2: "))
marks3 = int(input("Enter marks for subject 3: "))
marks4 = int(input("Enter marks for subject 4: "))
marks5 = int(input("Enter marks for subject 5: "))
avg = (marks1+marks2+marks3+marks4+marks5) / 5
print("Average marks:", avg)
if avg > 90:
    print("Grade: O")
elif avg > 80:
    print("Grade: A+")
elif avg > 70:
    print("Grade: A")
elif avg > 60:
    print("Grade: B+")
elif avg > 50:
    print("Grade: B")
elif avg > 40:
    print("Grade: C")
else:
    print("Grade: Fail")
# Out:
# Enter marks for subject 1: 23
# Enter marks for subject 2: 32
# Enter marks for subject 3: 34
# Enter marks for subject 4: 21
# Enter marks for subject 5: 12
# Average marks: 24.4
# Grade: Fail

# %%
#Problem6: Check whether a year is leap or not

year = int(input("Enter a year: "))
if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print(year, "is a Leap Year")
else:
    print(year, "is not a Leap Year")
# Out:
# Enter a year: 2013
# 2013 is not a Leap Year

# %%
#Problem 7: Python program to check if a date is valid and print the incremented date if it is valid:
# Input date
d = int(input("Enter day: "))
m = int(input("Enter month: "))
y = int(input("Enter year: "))


if m == 2:
    if (y % 4 == 0 and y % 100 != 0) or (y % 400 == 0):
        max_days = 29
    else:
        max_days = 28
elif m == 4 or m == 6 or m == 9 or m == 11:
    max_days = 30
elif m >= 1 and m <= 12:
    max_days = 31
else:
    max_days = 0

if d < 1 or d > max_days:
    print("Invalid Date")
else:
    print("Valid Date")

    # Increment date
    d = d + 1
    if d > max_days:
        d = 1
        m = m + 1
        if m > 12:
            m = 1
            y = y + 1

    print("Next Date:", d, "/", m, "/", y)
# Out:
# Enter day: 29
# Enter month: 02
# Enter year: 2023
# Invalid Date

# %%
'Write a python program to calculate the gross salary of an employee based on basic salary'
'If basic <= 10000: HRA = 20%,DA = 80%'
'If basic <= 20000: HRA = 25%,DA = 90%'
'Otherwise,HRA = 30%,DA = 95%'
basic=int(input("Enter the current salary"))
if basic <= 10000:
         hra = 0.20 * basic
         da = 0.80 * basic
elif basic <= 20000:
         hra = 0.25 * basic
         da = 0.90 * basic
else:
         hra = 0.30 * basic
         da = 0.95 * basic

gross_salary = basic + hra + da
print("The gross salary is:",gross_salary)
# Out:
# Enter the current salary12000
# The gross salary is: 25800.0
